# %% [markdown]
# # Solving Euler Bernoulli ODE with SymPy

# %%
import sympy as sym
sym.init_printing()

# %%
EI, q_z, x, L = sym.symbols('EI, q_z, x, L')
w = sym.Function('w')

ODE_bending = sym.Eq(w(x).diff(x, 4) *EI, q_z)
display(ODE_bending)
# Out:
#      4
#     d
# EI⋅───(w(x)) = q_z
#      4
#    dx

# %%
w = sym.dsolve(ODE_bending, w(x)).rhs
display(w)
# Out:
#                                  4
#                 2       3   q_z⋅x
# C₁ + C₂⋅x + C₃⋅x  + C₄⋅x  + ──────
#                             24⋅EI

# %%
phi = -w.diff(x)
kappa = phi.diff(x)
M = EI * kappa
V = M.diff(x)
eq1 = sym.Eq(w.subs(x,0),0)
eq2 = sym.Eq(phi.subs(x,0),0)
eq3 = sym.Eq(M.subs(x,L),0)
eq4 = sym.Eq(V.subs(x,L),0)
C_sol = sym.solve([eq1, eq2, eq3, eq4 ], sym.symbols('C1, C2, C3, C4'))
display(C_sol)
# Out:
# ⎧                   2                 ⎫
# ⎪                  L ⋅q_z      -L⋅q_z ⎪
# ⎨C₁: 0, C₂: 0, C₃: ──────, C₄: ───────⎬
# ⎪                   4⋅EI         6⋅EI ⎪
# ⎩                                     ⎭

# %%
w.subs(C_sol)
# Out:
#  2      2          3        4
# L ⋅q_z⋅x    L⋅q_z⋅x    q_z⋅x
# ───────── - ──────── + ──────
#    4⋅EI       6⋅EI     24⋅EI

# %% [markdown]
# Derivation of the stiffness matrix of euler bernoulli beam

# %%
w_1, w_2, phi_1, phi_2 = sym.symbols('w_1, w_2, phi_1, phi_2')
w = w.subs(q_z,0)
phi = -w.diff(x)
eq1 = sym.Eq(w.subs(x,0),w_1)
eq2 = sym.Eq(w.subs(x,L),w_2)
eq3 = sym.Eq(phi.subs(x,0),phi_1)
eq4 = sym.Eq(phi.subs(x,L),phi_2)
C_sol = sym.solve([eq1, eq2, eq3, eq4 ], sym.symbols('C1, C2, C3, C4'))
display(C_sol)
# Out:
# ⎧                     2⋅L⋅φ₁ + L⋅φ₂ - 3⋅w₁ + 3⋅w₂      -L⋅φ₁ - L⋅φ₂ + 2⋅w₁ - 2
# ⎪C₁: w₁, C₂: -φ₁, C₃: ───────────────────────────, C₄: ───────────────────────
# ⎨                                   2                               3
# ⎪                                  L                               L
# ⎩
#
# ⋅w₂⎫
# ───⎪
#    ⎬
#    ⎪
#    ⎭

# %%
w = sym.collect(w.subs(C_sol).expand(),[w_1,w_2,phi_1,phi_2, q_z])
display(w)
phi = -w.diff(x)
kappa = phi.diff(x).subs(C_sol)
M = EI * kappa
V = M.diff(x)
F_1_z, F_2_z, T_1_y, T_2_y = sym.symbols('F_1_z, F_2_z, T_1_y, T_2_y')

eq5 = sym.Eq(-V.subs(x,0), F_1_z)
eq6 = sym.Eq(V.subs(x,L), F_2_z)
eq7 = sym.Eq(-M.subs(x,0), T_1_y)
eq8 = sym.Eq(M.subs(x,L), T_2_y)
display(eq5, eq6, eq7, eq8)
# Out:
#    ⎛        2    3⎞      ⎛ 2    3⎞      ⎛       2      3⎞      ⎛   2      3⎞
#    ⎜     2⋅x    x ⎟      ⎜x    x ⎟      ⎜    3⋅x    2⋅x ⎟      ⎜3⋅x    2⋅x ⎟
# φ₁⋅⎜-x + ──── - ──⎟ + φ₂⋅⎜── - ──⎟ + w₁⋅⎜1 - ──── + ────⎟ + w₂⋅⎜──── - ────⎟
#    ⎜      L      2⎟      ⎜L     2⎟      ⎜      2      3 ⎟      ⎜  2      3 ⎟
#    ⎝            L ⎠      ⎝     L ⎠      ⎝     L      L  ⎠      ⎝ L      L  ⎠
#     ⎛6⋅φ₁   6⋅φ₂   12⋅w₁   12⋅w₂⎞
# -EI⋅⎜──── + ──── - ───── + ─────⎟ = F_1_z
#     ⎜  2      2       3       3 ⎟
#     ⎝ L      L       L       L  ⎠
#    ⎛6⋅φ₁   6⋅φ₂   12⋅w₁   12⋅w₂⎞
# EI⋅⎜──── + ──── - ───── + ─────⎟ = F_2_z
#    ⎜  2      2       3       3 ⎟
#    ⎝ L      L       L       L  ⎠
#     ⎛  4⋅φ₁   2⋅φ₂   6⋅w₁   6⋅w₂⎞
# -EI⋅⎜- ──── - ──── + ──── - ────⎟ = T_1_y
#     ⎜   L      L       2      2 ⎟
#     ⎝                 L      L  ⎠
#    ⎛2⋅φ₁   4⋅φ₂   6⋅w₁   6⋅w₂⎞
# EI⋅⎜──── + ──── - ──── + ────⎟ = T_2_y
#    ⎜ L      L       2      2 ⎟
#    ⎝               L      L  ⎠

# %%
A, b = sym.linear_eq_to_matrix([eq5,eq7, eq6, eq8], [w_1, phi_1, w_2, phi_2])
display(A,b)
# Out:
# ⎡ 12⋅EI   -6⋅EI   -12⋅EI   -6⋅EI ⎤
# ⎢ ─────   ──────  ───────  ──────⎥
# ⎢    3       2        3       2  ⎥
# ⎢   L       L        L       L   ⎥
# ⎢                                ⎥
# ⎢-6⋅EI     4⋅EI    6⋅EI     2⋅EI ⎥
# ⎢──────    ────    ────     ──── ⎥
# ⎢   2       L        2       L   ⎥
# ⎢  L                L            ⎥
# ⎢                                ⎥
# ⎢-12⋅EI    6⋅EI    12⋅EI    6⋅EI ⎥
# ⎢───────   ────    ─────    ──── ⎥
# ⎢    3       2        3       2  ⎥
# ⎢   L       L        L       L   ⎥
# ⎢                                ⎥
# ⎢-6⋅EI     2⋅EI    6⋅EI     4⋅EI ⎥
# ⎢──────    ────    ────     ──── ⎥
# ⎢   2       L        2       L   ⎥
# ⎣  L                L            ⎦
# ⎡F_1_z⎤
# ⎢     ⎥
# ⎢T_1_y⎥
# ⎢     ⎥
# ⎢F_2_z⎥
# ⎢     ⎥
# ⎣T_2_y⎦
